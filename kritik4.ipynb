# %%
import numpy as np
import matplotlib.pyplot as plt

# Perform gradient descent to find the minimum of a function
def gradient_descent(f, learning_rate, initial_point):
    # Approximate the derivative (slope) of the function at a given point
    def deriv(f, base_point):
        return (f(base_point + 10**(-10)) - f(base_point - 10**(-10))) / (2 * 10**(-10))

    # Lists to track x values (inputs) and their corresponding f(x) values (outputs)
    x_coords = [initial_point]  
    y_coords = [f(initial_point)]  # Initial function value

    # Perform gradient descent for 1000 iterations
    for _ in range(1000):
        # Calculate the gradient at the current x value
        gradient = deriv(f, x_coords[-1])
        # Update x value in the direction of the negative gradient
        update = -learning_rate * gradient
        x_coords.append(x_coords[-1] + update)  # Append new x value
        # Append the corresponding function value
        y_coords.append(f(x_coords[-1]))

    # Define the range of x values for plotting the function
    plot_range = np.linspace(min(x_coords) - 0.5, max(x_coords) + 0.5, 1000)
    function_range = [f(i) for i in plot_range]

    # Plot the function and the gradient descent path
    plt.plot(plot_range, function_range, label='Function f(x)')
    plt.plot(x_coords, y_coords, marker='o', color='r', label='Gradient Descent Steps')
    plt.xlabel('X')
    plt.ylabel('f(X)')
    plt.title('Gradient Descent: Minimizing a Function') 
    plt.legend()
    plt.show()

    # Return the x value of the minimum and its corresponding f(x) value
    return round(x_coords[-1], 3), round(y_coords[-1], 3)

# Define the function to be minimized
def f(x):
    return x**2

# Set the learning rate and starting point for gradient descent
learning_rate = 0.1
initial_point = 3

# Run the gradient descent algorithm and print the results
optimal_point, optimal_value = gradient_descent(f, learning_rate, initial_point)
print("Optimal Point:", optimal_point)  # x value at which f(x) is minimized
print("Optimal Value:", optimal_value)  # Minimum function value
# Out:
# Optimal Point: 0.0
# Optimal Value: 0.0

# %%
# 
import numpy as np
import matplotlib.pyplot as plt

# Perform gradient descent to find the minimum of a function
def gradient_descent(f, learning_rate, initial_point):
    # Approximate the derivative (slope) of the function at a given point
    def deriv(f, base_point):
        return (f(base_point + 10**(-10)) - f(base_point - 10**(-10))) / (2 * 10**(-10))

    # Lists to track x values (inputs) and their corresponding f(x) values (outputs)
    x_coords = [initial_point]  
    y_coords = [f(initial_point)]  # Initial function value

    # Perform gradient descent for 1000 iterations
    for _ in range(1000):
        # Calculate the gradient at the current x value
        gradient = deriv(f, x_coords[-1])
        # Update x value in the direction of the negative gradient
        update = -learning_rate * gradient
        x_coords.append(x_coords[-1] + update)  # Append new x value
        # Append the corresponding function value
        y_coords.append(f(x_coords[-1]))

    # Define the range of x values for plotting the function
    plot_range = np.linspace(min(x_coords) - 0.5, max(x_coords) + 0.5, 1000)
    function_range = [f(i) for i in plot_range]

    # Plot the function and the gradient descent path
    plt.plot(plot_range, function_range, label='Function f(x)')
    plt.plot(x_coords, y_coords, marker='o', color='r', label='Gradient Descent Steps')
    plt.xlabel('X')
    plt.ylabel('f(X)')
    plt.title('Gradient Descent: Minimizing a Quartic Function') 
    plt.legend()
    plt.show()

    # Return the x value of the minimum and its corresponding f(x) value
    return round(x_coords[-1], 3), round(y_coords[-1], 3)

# Define the quartic function to be minimized
def f(x):
    return x**4 - 2*x**2

# Set the learning rate and starting point for gradient descent
learning_rate = 0.01
initial_point = 1.5  # Use -1.5, 0.5, or 1.5 to find all critical points

# Run the gradient descent algorithm and print the results
optimal_point, optimal_value = gradient_descent(f, learning_rate, initial_point)
print("Optimal Point:", optimal_point)  # x value at which f(x) is minimized
print("Optimal Value:", optimal_value)  # Minimum function value
# Out:
# Optimal Point: 1.0
# Optimal Value: -1.0

# %%
#bullet 3: x to the x
import numpy as np
import matplotlib.pyplot as plt

# This function uses gradient descent to find the lowest point (minimum) of a function
def gradient_descent(f, learning_rate, initial_point):
    # calculates the slope (derivative) of the function at a given point
    def deriv(f, base_point):
        return (f(base_point + 10**(-10)) - f(base_point - 10**(-10))) / (2 * 10**(-10))

    # Lists to keep track of the x values and their corresponding y (function) values
    x_coords = [initial_point]  
    y_coords = [f(initial_point)]  # Calculate the function value at the start

    # Do the gradient descent for 1000 steps
    for _ in range(1000):
        # Find the slope of the function at the current x value
        gradient = deriv(f, x_coords[-1])
        # update x as it moves down the slope
        update = -learning_rate * gradient
        x_coords.append(x_coords[-1] + update)  # add the new x value to the list
        # Calculate and store the function value at the new x value
        y_coords.append(f(x_coords[-1]))

    # prepare points to draw the function curve
    plot_range = np.linspace(min(x_coords) - 0.5, max(x_coords) + 0.5, 1000)
    function_range = [f(i) for i in plot_range]

    #plotting
    plt.plot(plot_range, function_range, label='Function f(x)')
    plt.plot(x_coords, y_coords, marker='o', color='r', label='Steps')
    plt.xlabel('X')
    plt.ylabel('f(X)')
    plt.title('Finding the Minimum with Gradient Descent') 
    plt.legend()
    plt.show()

    # Return the final x value (best guess for minimum) and the function value at that x
    return round(x_coords[-1], 3), round(y_coords[-1], 3)

# This is the function (3) we are trying to minimize (code for this block is from assignment)
def f(x):
    if x > 0: 
        return x ** x 
    elif x == 0: 
        return 1 
    else: 
        return abs(x) ** abs(x)

# set learning rate and the starting point
learning_rate = 0.01
initial_point = 1.5

# Run the gradient descent function and print the results
optimal_point, optimal_value = gradient_descent(f, learning_rate, initial_point)
print("Optimal Point:", optimal_point)  #this is the x value where the function is smallest
print("Optimal Value:", optimal_value)  #this is the smallest function value
# Out:
# Optimal Point: 0.368
# Optimal Value: 0.692

# %%
#bullet 4: absolute
import numpy as np
import matplotlib.pyplot as plt

# This function uses gradient descent to find the lowest point (minimum) of a function
def gradient_descent(f, learning_rate, initial_point):
    # calculates the slope (derivative) of the function at a given point
    def deriv(f, base_point):
        return (f(base_point + 10**(-10)) - f(base_point - 10**(-10))) / (2 * 10**(-10))

# Lists to keep track of the x values and their corresponding y (function) values
    x_coords = [initial_point]  
    y_coords = [f(initial_point)]  # Calculate the function value at the start

# Do the gradient descent for 1000 steps
    for _ in range(1000):
        # Find the slope of the function at the current x value
        gradient = deriv(f, x_coords[-1])
        # update x as it moves down the slope
        update = -learning_rate * gradient
        x_coords.append(x_coords[-1] + update)  # add the new x value to the list
        # Calculate and store the function value at the new x value
        y_coords.append(f(x_coords[-1]))

# prepare points to draw the function curve
    plot_range = np.linspace(min(x_coords) - 0.5, max(x_coords) + 0.5, 1000)
    function_range = [f(i) for i in plot_range]

# plotting
    plt.plot(plot_range, function_range, label='Function f(x)')
    plt.plot(x_coords, y_coords, marker='o', color='r', label='Steps')
    plt.xlabel('X')
    plt.ylabel('f(X)')
    plt.title('Finding the Minimum with Gradient Descent') 
    plt.legend()
    plt.show()

# Return the final x value (best guess for minimum) and the function value at that x
    return round(x_coords[-1], 3), round(y_coords[-1], 3)

# This is the function we are trying to minimize
def f(x):
    return abs(x)  # absolute value function

# set the learning rate and the starting point
learning_rate = 0.1
initial_point = 1.5

# Run the gradient descent function and print the results
optimal_point, optimal_value = gradient_descent(f, learning_rate, initial_point)
print("Optimal Point:", optimal_point)  # this is the x value where the function is smallest
print("Optimal Value:", optimal_value)  # this is the smallest function value


# this doesn't work because the derivative is undefined at x=0 for an absolute function, so this method of determining minimums is not functional as it relies on the derivative to find minimum
# Out:
# Optimal Point: -0.1
# Optimal Value: 0.1

# %%
import numpy as np
import matplotlib.pyplot as plt

# Perform gradient descent to find the minimum of a function
def gradient_descent(f, learning_rate, initial_point):
    # Approximate the derivative (slope) of the function at a given point
    def deriv(f, base_point):
        return (f(base_point + 10**(-10)) - f(base_point - 10**(-10))) / (2 * 10**(-10))

    # Lists to track x values (inputs) and their corresponding f(x) values (outputs)
    x_coords = [initial_point]  
    y_coords = [f(initial_point)]  # Initial function value

    # Perform gradient descent for 1000 iterations
    for _ in range(1000):
        # Calculate the gradient at the current x value
        gradient = deriv(f, x_coords[-1])
        # Update x value in the direction of the negative gradient
        update = -learning_rate * gradient
        x_coords.append(x_coords[-1] + update)  # Append new x value
        # Append the corresponding function value
        y_coords.append(f(x_coords[-1]))

    # Define the range of x values for plotting the function
    plot_range = np.linspace(min(x_coords) - 0.5, max(x_coords) + 0.5, 1000)
    function_range = [f(i) for i in plot_range]

    # Plot the function and the gradient descent path
    plt.plot(plot_range, function_range, label='Function f(x)')
    plt.plot(x_coords, y_coords, marker='o', color='r', label='Gradient Descent Steps')
    plt.xlabel('X')
    plt.ylabel('f(X)')
    plt.title('Gradient Descent: Minimizing a Function') 
    plt.legend()
    plt.show()

    # Return the x value of the minimum and its corresponding f(x) value
    return round(x_coords[-1], 3), round(y_coords[-1], 3)

# Define the function to be minimized
def f(x):
    return x**2

# Set the learning rate and starting point for gradient descent
learning_rate = 0.1
initial_point = 3

# Run the gradient descent algorithm and print the results
optimal_point, optimal_value = gradient_descent(f, learning_rate, initial_point)
print("Optimal Point:", optimal_point)  # x value at which f(x) is minimized
print("Optimal Value:", optimal_value)  # Minimum function value
# Out:
# Optimal Point: 0.0
# Optimal Value: 0.0
