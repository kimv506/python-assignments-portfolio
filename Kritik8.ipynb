# %%
#4a.
import numpy as np

def gradient_descent(x0, y0, f, alpha, num_iterations):
    x, y = x0, y0 
    for i in range(num_iterations):
        grad_x,grad_y=grad_f_1(x, y)
        x = x-alpha*grad_x
        y = y-alpha*grad_y
    return x, y

#b

def fun_1(x, y):
    return x**2 + y**2

def grad_f_1(x, y):
    grad_x=2*x
    grad_y=2*y
    return grad_x, grad_y

# %%
#testcase 1 a/b
gradient_descent(0.1,0.1,fun_1,0.1,10)
# Out:
# (0.010737418240000003, 0.010737418240000003)

# %%
#testcase 2 a/b
gradient_descent(-1,1,fun_1,0.01,100)
# Out:
# (-0.13261955589475316, 0.13261955589475316)

# %%
#4b.
import numpy as np

def fun_1(x, y):
    return x**2 + y**2

def grad_f_1(x, y):
    grad_x=2*x
    grad_y=2*y
    return grad_x, grad_y

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

def gradient_descent(x0, y0, f, alpha, num_iterations):
    x, y = x0, y0 
    for i in range(num_iterations):
        grad_x,grad_y=grad_f_1(x, y)
        x = x-alpha*grad_x
        y = y-alpha*grad_y
    return x, y

def fun_1(x, y):
    return x**2 + y**2

def grad_f_1(x, y):
    grad_x=2*x
    grad_y=2*y
    return grad_x, grad_y

#make graph and plot
X = np.linspace(-5, 5, 100)
Y = np.linspace(-5, 5, 100)
x, y = np.meshgrid(X, Y)
z = fun_1(x, y)  # Calculate z using the function over the grid
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_surface(x, y, z, cmap='viridis', edgecolor='none')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#8c.
def fun_2(x, y):
  return 1-np.exp(-x**2-(y-2)**2)-2*np.exp(-x**2-(y+2)**2)

def grad_f_2(x, y):
    grad_x = 2*x*np.exp(-x**2-(y-2)**2)+4*x*np.exp(-x**2-(y+2)**2)
    grad_y = 2*(y-2)*np.exp(-x**2-(y-2)**2)+4*(y+2)*np.exp(-x**2-(y+2)**2)
    return grad_x, grad_y

# same as in a, just wanted to separate this with cells and was getting weird errors so i put it again
def gradient_descent(x0, y0, f, alpha, num_iterations):
    x, y = x0, y0 
    for i in range(num_iterations):
        grad_x, grad_y = grad_f_1(x, y)
        x = x-alpha*grad_x
        y = y-alpha*grad_y
    return x, y

#testcase 1 c:
gradient_descent(0,1,fun_2,0.01,1000)

import numpy as np


def gradient_descent(x0, y0,f, grad_f, alpha, num_iterations):

    x, y = x0, y0 # Initialize x and y with the initial point
    for i in range(num_iterations):
# obtain the gradient of f at (x, y)
        y_prime, x_prime = grad_f(x,y)
        x = x - alpha*x_prime


    for i in range(num_iterations):
        y= y - alpha*y_prime
   
    return (x,y)
def fun_1(x,y):
    return x**2+y**2
def grad_f_1(x,y):

# define variables
    y_prime = 2*x

    x_prime = 2*y
    return y_prime, x_prime

t1 = gradient_descent(0.1,0.1, fun_1, grad_f_1,0.1,10)
print ("t1:", t1)
t1: (-0.10000000000000003, 0.2600000000000001)
import numpy as np
def fun_2(x,y):
    return 1-np.exp(-x**2-(y-2)**2)-2*np.exp(-x**2-(y+2)**2)


def grad_f_2(x,y):
    grad_x = alpha*(np.exp**(-2*x))*(2*x)
    grad_y = aplpha*np.exp**(-2*y)*2*y
    return grad_x, grad_y

from mpl_toolkits import mplot3d #for 3D plots
import matplotlib.pyplot as plt #usual matplotlib
# %matplotlib widget
X=np.linspace(-5,5,100)
Y=np.linspace(-5,5,100)
x,y=np.meshgrid(X,Y)
z= 1-np.exp(-x**2-(y-2)**2)-2*np.exp(-x**2-(y+2)**2)

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_surface(x, y, z,cmap='viridis', edgecolor='none')
# Out:
# t1: (-0.10000000000000003, 0.2600000000000001)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
